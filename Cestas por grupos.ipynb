# %% [markdown]
# ***Color manual***
#
# <div class="alert alert-block alert-success">
# <b>Green - Libraries</b>
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Blue - Information</b>
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Red - Problems</b>
# </div>
#
# ***

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Import libraries</b>
# </div>

# %%
import numpy as np
import chart_studio
import pandas as pd
import plotly.graph_objs as go
import chart_studio.plotly as py

chart_studio.tools.set_config_file(world_readable = True, sharing = 'public')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Load the Data, set index and info about data</b>
# </div>

# %%
df = pd.read_excel('Cestas.xlsx', index_col = 'Alimento', sheet_name = 'Data frame')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, Açucar to Sal
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Faixa etária          26 non-null     object
#  1   Quantidade de alunos  26 non-null     int64
#  2   Quantidade/aluno      26 non-null     int64
#  3   kg/unidade            26 non-null     float64
#  4   Preço/unidade         26 non-null     float64
#  5   kg/aluno              26 non-null     float64
#  6   Preço/aluno           26 non-null     float64
#  7   kg total              26 non-null     float64
#  8   Preço total           26 non-null     float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pivot table sorted by preço total</b>
# </div>

# %%
pivot_all = pd.pivot_table(df, index = ['Alimento','Faixa etária'], 
                               values = ['Quantidade/aluno', 'kg/unidade', 'Preço/unidade', 'kg/aluno', 
                                         'Preço/aluno', 'kg total', 'Preço total'],
                               aggfunc = np.sum, fill_value = 0)


column_order = ['Quantidade/aluno', 'kg/unidade', 'Preço/unidade', 'kg/aluno', 
                'Preço/aluno', 'kg total', 'Preço total']

pivot_all = pivot_all.reindex(column_order, axis = 1)

pivot_all = pivot_all.sort_values(by = ['Preço total'], ascending = False)

pivot_all
# Out:
#                                       Quantidade/aluno  kg/unidade  \
# Alimento            Faixa etária
# Charque traseiro    6 anos a 15 anos                 1        0.50
# Feijão              6 anos a 15 anos                 1        1.00
# Biscoito maria      6 anos a 15 anos                 1        0.40
# Arroz               6 anos a 15 anos                 2        1.00
# Biscoito cracker    6 anos a 15 anos                 1        0.40
# Leite               3 anos a 6 anos                  4        0.20
# Macarrão            6 anos a 15 anos                 2        0.50
# Leite               6 meses a 3 anos                 4        0.20
# Óleo                6 anos a 15 anos                 1        0.90
# Farinha de mandioca 6 anos a 15 anos                 1        1.00
# Massa de milho      6 anos a 15 anos                 2        0.50
# Açucar              6 anos a 15 anos                 1        1.00
# Mucilon             6 meses a 3 anos                 2        0.23
# Feijão              3 anos a 6 anos                  1        1.00
# Biscoito maria      3 anos a 6 anos                  1        0.40
# Feijão              6 meses a 3 anos                 1        1.00
# Arroz               3 anos a 6 anos                  2        1.00
# Biscoito cracker    3 anos a 6 anos                  1        0.40
# Macarrão            3 anos a 6 anos                  2        0.50
# Óleo                3 anos a 6 anos                  1        0.90
# Sal                 6 anos a 15 anos                 1        1.00
# Massa de milho      3 anos a 6 anos                  2        0.50
# Arroz               6 meses a 3 anos                 1        1.00
# Açucar              3 anos a 6 anos                  1        1.00
# Macarrão            6 meses a 3 anos                 1        0.50
# Sal                 3 anos a 6 anos                  1        1.00
#
#                                       Preço/unidade  kg/aluno  Preço/aluno  \
# Alimento            Faixa etária
# Charque traseiro    6 anos a 15 anos          12.29      0.50        12.29
# Feijão              6 anos a 15 anos           6.29      1.00         6.29
# Biscoito maria      6 anos a 15 anos           5.89      0.40         5.89
# Arroz               6 anos a 15 anos           2.89      2.00         5.78
# Biscoito cracker    6 anos a 15 anos           4.49      0.40         4.49
# Leite               3 anos a 6 anos            4.69      0.80        18.76
# Macarrão            6 anos a 15 anos           1.99      1.00         3.98
# Leite               6 meses a 3 anos           4.69      0.80        18.76
# Óleo                6 anos a 15 anos           3.59      0.90         3.59
# Farinha de mandioca 6 anos a 15 anos           2.99      1.00         2.99
# Massa de milho      6 anos a 15 anos           1.49      1.00         2.98
# Açucar              6 anos a 15 anos           2.29      1.00         2.29
# Mucilon             6 meses a 3 anos           4.89      0.46         9.78
# Feijão              3 anos a 6 anos            6.29      1.00         6.29
# Biscoito maria      3 anos a 6 anos            5.89      0.40         5.89
# Feijão              6 meses a 3 anos           6.29      1.00         6.29
# Arroz               3 anos a 6 anos            2.89      2.00         5.78
# Biscoito cracker    3 anos a 6 anos            4.49      0.40         4.49
# Macarrão            3 anos a 6 anos            1.99      1.00         3.98
# Óleo                3 anos a 6 anos            3.59      0.90         3.59
# Sal                 6 anos a 15 anos           0.79      1.00         0.79
# Massa de milho      3 anos a 6 anos            1.49      1.00         2.98
# Arroz               6 meses a 3 anos           2.89      1.00         2.89
# Açucar              3 anos a 6 anos            2.29      1.00         2.29
# Macarrão            6 meses a 3 anos           1.99      0.50         1.99
# Sal                 3 anos a 6 anos            0.79      1.00         0.79
#
#                                       kg total  Preço total
# Alimento            Faixa etária
# Charque traseiro    6 anos a 15 anos   4845.50    119102.39
# Feijão              6 anos a 15 anos   9691.00     60956.39
# Biscoito maria      6 anos a 15 anos   3876.40     57079.99
# Arroz               6 anos a 15 anos  19382.00     56013.98
# Biscoito cracker    6 anos a 15 anos   3876.40     43512.59
# Leite               3 anos a 6 anos    1726.40     40484.08
# Macarrão            6 anos a 15 anos   9691.00     38570.18
# Leite               6 meses a 3 anos   1598.40     37482.48
# Óleo                6 anos a 15 anos   8721.90     34790.69
# Farinha de mandioca 6 anos a 15 anos   9691.00     28976.09
# Massa de milho      6 anos a 15 anos   9691.00     28879.18
# Açucar              6 anos a 15 anos   9691.00     22192.39
# Mucilon             6 meses a 3 anos    919.08     19540.44
# Feijão              3 anos a 6 anos    2158.00     13573.82
# Biscoito maria      3 anos a 6 anos     863.20     12710.62
# Feijão              6 meses a 3 anos   1998.00     12567.42
# Arroz               3 anos a 6 anos    4316.00     12473.24
# Biscoito cracker    3 anos a 6 anos     863.20      9689.42
# Macarrão            3 anos a 6 anos    2158.00      8588.84
# Óleo                3 anos a 6 anos    1942.20      7747.22
# Sal                 6 anos a 15 anos   9691.00      7655.89
# Massa de milho      3 anos a 6 anos    2158.00      6430.84
# Arroz               6 meses a 3 anos   1998.00      5774.22
# Açucar              3 anos a 6 anos    2158.00      4941.82
# Macarrão            6 meses a 3 anos    999.00      3976.02
# Sal                 3 anos a 6 anos    2158.00      1704.82

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pivot table of alimento</b>
# </div>

# %%
pivot_one = pd.pivot_table(df, index = ['Alimento'],
                               values = ['Preço total', 'kg total'],
                               aggfunc = np.sum, fill_value = 0)

pivot_one
# Out:
#                      Preço total  kg total
# Alimento
# Arroz                   74261.44  25696.00
# Açucar                  27134.21  11849.00
# Biscoito cracker        53202.01   4739.60
# Biscoito maria          69790.61   4739.60
# Charque traseiro       119102.39   4845.50
# Farinha de mandioca     28976.09   9691.00
# Feijão                  87097.63  13847.00
# Leite                   77966.56   3324.80
# Macarrão                51135.04  12848.00
# Massa de milho          35310.02  11849.00
# Mucilon                 19540.44    919.08
# Sal                      9360.71  11849.00
# Óleo                    42537.91  10664.10

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Data frame to make plot</b>
# </div>

# %%
df_ini = pd.read_excel('Cestas.xlsx', sheet_name = '6 meses a 3 anos')
df_ini.set_index('alimento', inplace = True)
df_ini.sort_index(inplace = True)

df_mei = pd.read_excel('Cestas.xlsx', sheet_name = '3 anos a 6 anos')
df_mei.set_index('alimento', inplace = True)
df_mei.sort_index(inplace = True)

df_fin = pd.read_excel('Cestas.xlsx', sheet_name = '6 anos a 15 anos')
df_fin.set_index('alimento', inplace = True)  
df_fin.sort_index(inplace = True)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Bar plot</b>
# </div>

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x = df_ini.index, y = df_ini['preço total'], 
    name = '6 meses a 3 anos',
    hoverinfo = 'x+y+text',
    marker_color = 'rgb(255, 255, 145)',
    marker_line_color = 'rgb(1,1,1)',
    marker_line_width = 2))

fig.add_trace(go.Bar(x = df_mei.index, y = df_mei['preço total'], 
    name = '3 anos a 6 anos', 
    hoverinfo = 'x+y+text',
    marker_color = 'rgb(115, 150, 200)',
    marker_line_color = 'rgb(1,1,1)',
    marker_line_width = 2))

fig.add_trace(go.Bar(x = df_fin.index, y = df_fin['preço total'],
    name = '6 anos a 15 anos',
    hoverinfo = 'x+y+text',
    marker_color ='rgb(190, 230, 160)',
    marker_line_color = 'rgb(1,1,1)',
    marker_line_width = 2))

fig.update_layout(barmode = 'stack', 
    title_text = 'Cestas por grupos', 
    title_x = 0.5,
    title_y = 0.9,
    legend = dict(x = 0, y = 1.5),
    legend_title='<b> Grupos </b>',
    xaxis_title = 'Alimentos',
    yaxis_title = 'Preço total',
    paper_bgcolor = 'rgba(1,1,1,1)',
    plot_bgcolor = 'rgba(1,1,1,1)',
    font = dict(
        family = 'Helvetica, Helvetica',
        size = 15,
        color = 'white'))

fig.update_yaxes(hoverformat = '.2f', showgrid = False)

py.iplot(fig, filename = 'Cestas por grupos', auto_open = False)
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~Empanator/151.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
